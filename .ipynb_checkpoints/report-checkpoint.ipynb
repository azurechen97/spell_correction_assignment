# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import math
import nltk
from nltk import word_tokenize
from nltk.corpus import reuters

# %%
with open('vocab.txt') as vocab_file:
    lines = vocab_file.readlines()
vocab = [line.strip() for line in lines]

# %%
vocab.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-915af4dbaf57> in <module>
# ----> 1 vocab.head()
#
# AttributeError: 'list' object has no attribute 'head'

# %%
testdata = pd.read_table('testdata.txt', header=None)
n = testdata.shape[0]

# %%
un_freq = nltk.FreqDist(reuters.words())
V = len(un_freq)

# %%
bigrams = nltk.bigrams(reuters.words())
bi_freq = nltk.FreqDist(bigrams)

# %%
letters = "abcdefghijklmnopqrstuvwxyz"
other = " -'"

# %%
def distance_1(word):
    total = {word}
    for i in range(0,len(word)):
        l = word[:i]
        r = word[i:]
        alphabet = letters
        if len(word) > 1 and i > 0:
            total.update(set([l[:i-1]+r[0]+l[i-1]+r[1:]])) #Transposition
            if i < len(word):
                alphabet = letters+other
        total.update(set([l+c+r for c in alphabet]+[l+r+c for c in alphabet])) #Insertion
        total.update(set([l+r[1:]])) #Deletion
        total.update(set([l+c+r[1:] for c in alphabet])) #Substitution
    return total

# %%
def distance_2(word):
    return set(d2 for d1 in distance_1(word) for d2 in distance_1(d1))

# %%
def log_smoothed_prob(pre,next):
    prob = math.log10((bi_freq[(pre,next)]+1))-math.log10((un_freq[pre]+V))
    return prob

# %%
def correction(pre,word,vocab):
    prob_dict = dict()
    for y in distance_1(word):
        if y in vocab:
            prob_dict[y]=log_smoothed_prob(pre,y)
    if len(prob_dict) == 0:
        return "Not Found"
    else:
        return max(prob_dict,key=prob_dict.get)

# %%
exist_real_word_errors = list()
for i in range(0,100):
    misspell_count = 0
    sentence = word_tokenize(testdata[2][i])
    for p, word in enumerate(sentence):
        if misspell_count == testdata[1][i]:
           break
        if word not in vocab:
            misspell_count += 1
            print(word+" "+correction(sentence[p-1],word,vocab))
    if misspell_count != testdata[1][i]:
        exist_real_word_errors.append([i, testdata[1][i] - misspell_count])
# Out:
# protectionst protectionist
# Tkyo Tokyo
# retaiation retaliation
# tases taxes
# busines business
# Taawin Not Found
# seriousnyss seriousness
# aganst against
# bililon billion
# sewll swell
# importsi imports
# Sheem Sheen
# wsohe Not Found
# Koreva Korea
# Japn Japan
# semicondctors semiconductors
# advantagne advantage
# Lawrenc Lawrence
# disadxantage disadvantage
# rxpoet Not Found
# conceern concern
# amtter matter
# cenntred centred
# trad trade
# Liberala Liberal
# inoclude include
# fcsial Not Found
# Representetive Representative
# ootput output
# methids methods
# producton production
# parep prep
# endergy energy
# Japnese Japanese
# Agencay Agency
# energyr energy
# pfovided provided
# imhorts imports
# incease increase
# quartee quarter
# expanted expanded
# Exeport Export
# clotcing clothing
# arnuod Not Found
# intehnational international
# markats markets
# aiagnst Not Found
# movament movement
# dotay Not Found
# racgo Not Found
# Coincul Not Found
# affecced affected
# evfect effect
# tobacoc tobacco
# rithee Not Found
# beng being
# rubbes rubber
# cautiousy cautiously
# safly safely
# Physicay Physical
# Rtbusoa Not Found
# rubebr rubber
# afte after
# Salh Saleh
# Nannggolai Not Found
# Amerrican American
# althlugh although
# locayll Not Found
# bilion billion
# broers brokers
# shepment shipment
# ltuRA Not Found
# Rivir River
# produc produce
# abouct about
# lovans loans
# Reutres Reuters
# inserview interview
# wihle while
# cuiqkly Not Found
# Somitumo Not Found
# conparable comparable
# agdeer Not Found
# ovesreas overseas
# plae place
# Klieinwort Kleinwort
# icrease increase
# Suoitomm Not Found
# Kmatsu Komatsu
# viraous Not Found
# thtree three
# recusities Not Found
# aapJn Not Found
# Kmatsu Komatsu
# businiss business

# %%
def correction(pre,word,vocab):
    prob_dict = dict()
    for y in distance_1(word):
        if y in vocab:
            prob_dict[y]=log_smoothed_prob(pre,y)
    if len(prob_dict) == 0:
        for y in distance_2(word):
            if y in vocab:
                prob_dict[y]=log_smoothed_prob(pre,y)
    if len(prob_dict) == 0:
        return "Not Found"
    else:
        return max(prob_dict,key=prob_dict.get)

# %%
exist_real_word_errors = list()
for i in range(0,100):
    misspell_count = 0
    sentence = word_tokenize(testdata[2][i])
    for p, word in enumerate(sentence):
        if misspell_count == testdata[1][i]:
           break
        if word not in vocab:
            misspell_count += 1
            print(word+" "+correction(sentence[p-1],word,vocab))
    if misspell_count != testdata[1][i]:
        exist_real_word_errors.append([i, testdata[1][i] - misspell_count])
# Out:
# protectionst protectionist
# Tkyo Tokyo
# retaiation retaliation
# tases taxes
# busines business
# Taawin Taiwan
# seriousnyss seriousness
# aganst against
# bililon billion
# sewll swell
# importsi imports
# Sheem Sheen
# wsohe some
# Koreva Korea
# Japn Japan
# semicondctors semiconductors
# advantagne advantage
# Lawrenc Lawrence
# disadxantage disadvantage
# rxpoet export
# conceern concern
# amtter matter
# cenntred centred
# trad trade
# Liberala Liberal
# inoclude include
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-3af20253642e> in <module>
#       8         if word not in vocab:
#       9             misspell_count += 1
# ---> 10             print(word+" "+correction(sentence[p-1],word,vocab))
#      11     if misspell_count != testdata[1][i]:
#      12         exist_real_word_errors.append([i, testdata[1][i] - misspell_count])
#
# <ipython-input-14-d876a0a735f5> in correction(pre, word, vocab)
#       6     if len(prob_dict) == 0:
#       7         for y in distance_2(word):
# ----> 8             if y in vocab:
#       9                 prob_dict[y]=log_smoothed_prob(pre,y)
#      10     if len(prob_dict) == 0:
#
# KeyboardInterrupt:

# %%
def correction(pre,word,vocab):
    prob_dict = dict()
    for y in distance_1(word):
        if y in vocab:
            prob_dict[y]=log_smoothed_prob(pre,y)
    if len(prob_dict) == 0:
        for y in distance_2(word):
            if y in vocab and bi_freq[(pre,y)] > 0:
                return y
    if len(prob_dict) == 0:
        return "Not Found"
    else:
        return max(prob_dict,key=prob_dict.get)

# %%
exist_real_word_errors = list()
for i in range(0,100):
    misspell_count = 0
    sentence = word_tokenize(testdata[2][i])
    for p, word in enumerate(sentence):
        if misspell_count == testdata[1][i]:
           break
        if word not in vocab:
            misspell_count += 1
            print(word+" "+correction(sentence[p-1],word,vocab))
    if misspell_count != testdata[1][i]:
        exist_real_word_errors.append([i, testdata[1][i] - misspell_count])
# Out:
# protectionst protectionist
# Tkyo Tokyo
# retaiation retaliation
# tases taxes
# busines business
# Taawin Taiwan
# seriousnyss seriousness
# aganst against
# bililon billion
# sewll swell
# importsi imports
# Sheem Sheen
# wsohe she
# Koreva Korea
# Japn Japan
# semicondctors semiconductors
# advantagne advantage
# Lawrenc Lawrence
# disadxantage disadvantage
# rxpoet export
# conceern concern
# amtter matter
# cenntred centred
# trad trade
# Liberala Liberal
# inoclude include
# fcsial fiscal
# Representetive Representative
# ootput output
# methids methods
# producton production
# parep prep
# endergy energy
# Japnese Japanese
# Agencay Agency
# energyr energy
# pfovided provided
# imhorts imports
# incease increase
# quartee quarter
# expanted expanded
# Exeport Export
# clotcing clothing
# arnuod around
# intehnational international
# markats markets
# aiagnst against
# movament movement
# dotay today
# racgo range
# Coincul Council
# affecced affected
# evfect effect
# tobacoc tobacco
# rithee either
# beng being
# rubbes rubber
# cautiousy cautiously
# safly safely
# Physicay Physical
# Rtbusoa Robusta
# rubebr rubber
# afte after
# Salh Saleh
# Nannggolai Nainggolan
# Amerrican American
# althlugh although
# locayll locally
# bilion billion
# broers brokers
# shepment shipment
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-3af20253642e> in <module>
#       8         if word not in vocab:
#       9             misspell_count += 1
# ---> 10             print(word+" "+correction(sentence[p-1],word,vocab))
#      11     if misspell_count != testdata[1][i]:
#      12         exist_real_word_errors.append([i, testdata[1][i] - misspell_count])
#
# <ipython-input-16-ef7097bc560f> in correction(pre, word, vocab)
#       7     if len(prob_dict) == 0:
#       8         for y in distance_2(word):
# ----> 9             if y in vocab and bi_freq[(pre,y)] > 0:
#      10                 return y
#      11     if len(prob_dict) == 0:
#
# KeyboardInterrupt:

# %%
result = testdata.drop(columns=1)

# %%
result
# Out:
#         0                                                  2
# 0       1  They told Reuter correspondents in Asian capit...
# 1       2  But some exporters said that while the conflic...
# 2       3  The U.S. Has said it will impose 300 mln dlrs ...
# 3       4  Unofficial Japanese estimates put the impact o...
# 4       5  We wouldn't be able to do busines, said a spok...
# 5       6  If the tariffs remain in pace for any length o...
# 6       7  In Taawin, businessmen and officials are also ...
# 7       8        We are aware of the seriousnyss of the U.S.
# 8       9  Threat aganst  Japan because it serves as a wa...
# 9      10  Taiwan had a trade trade surplus of 15.6 bilil...
# 10     11  The surplus helped sewll Taiwan's foreign exch...
# 11     12  We must quickly open our markets, remove trade...
# 12     13  Retaliation, said  Paul Sheem, chairman of tex...
# 13     14  A senior official of South Korea's trade promo...
# 14     15  Last year South Koreva had a trade surplus of ...
# 15     16  In Malaysia, trade officers and businessmen sa...
# 16     17  In Hong Kong, where newspapers have alleged Ja...
# 17     18  But other businessmen said such  a short-term ...
# 18     19  That is a very short-term view, said Lawrenc M...
# 19     20  If the whoe purpose is to prevent imports, one...
# 20     21  Much more serious for Hong Kong  is the disadx...
# 21     22  The U.S. Last year was Hong Kong's biggest rxp...
# 22     23  The Australian government is awaiting the outc...
# 23     24  This kind of deterioration in trade relations ...
# 24     25  He said Australia's concerns cenntred on coal ...
# 25     26  Meanwhile U.S.-Japanese diplomatic manoeuvres ...
# 26     27  Japan's ruling Liberala Democratic Party yeste...
# 27     28  The measures proposed inoclude a large supplem...
# 28     29  They also call for stepped-up spending as an e...
# 29     30  Deputy U.S. Trade Representetive Michael Smith...
# ..    ...                                                ...
# 970   971  Hrllee said thedre was a danger of renewed pri...
# 971   972  The pricing behavior of American produhcers in...
# 972   973  Widespread domestic price rises in response to...
# 973   974  A returun to the stagflatiion of the late 1970...
# 974   975  He said we at the Federal Reserve will have to...
# 975   976  Heller said said the government should also ex...
# 976   977  The nmpositioi of new taxes would tend to reki...
# 977   978  He said the U.S. economy should expand by near...
# 978   979  A free trad agreement currently being negotiat...
# 979   980  But it said a 41.5 mln dlr non-cash writeoff o...
# 980   981  Eneergy Development Partners, is a limoited pa...
# 981   982  Full year ervenues totalfed 23.7 mln dlrs, the...
# 982   983  It said porved reserves at December 31 totaled...
# 983   984  Canadian Finance Minister Michael Wilson said ...
# 984   985  Asked if he was satisfaed with West German and...
# 985   986  French Finance Mrnistei Edouard Baelladur, mea...
# 986   987  Finance ministers and censral bankers of Brita...
# 987   988  Japanese officials and Bundesbank President Ka...
# 988   989  Thare was no sign, however, of the Italian del...
# 989   990  European mnetary officials said later that the...
# 990   991  This meant that a full bdown meeting of the Gr...
# 991   992  The whole tremd of inspection for the last 10 ...
# 992   993  The American cogsumer has little reason to fee...
# 993   994  Conpany management is less concerned about the...
# 994   995  Kenneth Morrison, staff associate at the Gover...
# 995   996  Morritson told of chicken fat for flavoring be...
# 996   997  Donald Houston, adminiustrator of the U.S. Agr...
# 997   998  FSIS inspects an edtimates 127 mln head of cat...
# 998   999  Houston said inspectieon programs have kept pa...
# 999  1000  He also said that, although he was confident t...
#
# [1000 rows x 2 columns]

# %%
for i in range(0,100):
    misspell_count = 0
    sentence = word_tokenize(testdata[2][i])
    for p, word in enumerate(sentence):
        if misspell_count == testdata[1][i]:
           break
        if word not in vocab:
            misspell_count += 1
            correct_word = correction(sentence[p-1],word,vocab)
            print(word+" "+correct_word)
            result[1][i][p] = correct_word
    if misspell_count != testdata[1][i]:
        exist_real_word_errors.append([i, testdata[1][i] - misspell_count])
# Out:
# protectionst protectionist
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-21d4932b7ec5> in <module>
#       9             correct_word = correction(sentence[p-1],word,vocab)
#      10             print(word+" "+correct_word)
# ---> 11             result[1][i][p] = correct_word
#      12     if misspell_count != testdata[1][i]:
#      13         exist_real_word_errors.append([i, testdata[1][i] - misspell_count])
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1

# %%
def correction(pre,word,vocab):
    prob_dict = dict()
    for y in distance_1(word):
        if y in vocab:
            prob_dict[y]=log_smoothed_prob(pre,y)
    if len(prob_dict) == 0:
        return word
    else:
        return max(prob_dict,key=prob_dict.get)

# %%
from nltk.tokenize.moses import MosesDetokenizer
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-25-3b35115b5058> in <module>
# ----> 1 from nltk.tokenize.moses import MosesDetokenizer
#
# ModuleNotFoundError: No module named 'nltk.tokenize.moses'

# %%
for i in range(0,100):
    misspell_count = 0
    sentence = word_tokenize(testdata[2][i])
    for p, word in enumerate(sentence):
        if misspell_count == testdata[1][i]:
           break
        if word not in vocab:
            misspell_count += 1
            correct_word = correction(sentence[p-1],word,vocab)
            print(word+" "+correct_word)
            result[1][i].replace(word,correct_word)
    if misspell_count != testdata[1][i]:
        exist_real_word_errors.append([i, testdata[1][i] - misspell_count])
# Out:
# protectionst protectionist
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-8c53cfcdafef> in <module>
#       9             correct_word = correction(sentence[p-1],word,vocab)
#      10             print(word+" "+correct_word)
# ---> 11             result[1][i].replace(word,correct_word)
#      12     if misspell_count != testdata[1][i]:
#      13         exist_real_word_errors.append([i, testdata[1][i] - misspell_count])
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1

# %%
result[1][2]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-27-ebca3d8e8b43> in <module>
# ----> 1 result[1][2]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 1

# %%
result
# Out:
#         0                                                  2
# 0       1  They told Reuter correspondents in Asian capit...
# 1       2  But some exporters said that while the conflic...
# 2       3  The U.S. Has said it will impose 300 mln dlrs ...
# 3       4  Unofficial Japanese estimates put the impact o...
# 4       5  We wouldn't be able to do busines, said a spok...
# 5       6  If the tariffs remain in pace for any length o...
# 6       7  In Taawin, businessmen and officials are also ...
# 7       8        We are aware of the seriousnyss of the U.S.
# 8       9  Threat aganst  Japan because it serves as a wa...
# 9      10  Taiwan had a trade trade surplus of 15.6 bilil...
# 10     11  The surplus helped sewll Taiwan's foreign exch...
# 11     12  We must quickly open our markets, remove trade...
# 12     13  Retaliation, said  Paul Sheem, chairman of tex...
# 13     14  A senior official of South Korea's trade promo...
# 14     15  Last year South Koreva had a trade surplus of ...
# 15     16  In Malaysia, trade officers and businessmen sa...
# 16     17  In Hong Kong, where newspapers have alleged Ja...
# 17     18  But other businessmen said such  a short-term ...
# 18     19  That is a very short-term view, said Lawrenc M...
# 19     20  If the whoe purpose is to prevent imports, one...
# 20     21  Much more serious for Hong Kong  is the disadx...
# 21     22  The U.S. Last year was Hong Kong's biggest rxp...
# 22     23  The Australian government is awaiting the outc...
# 23     24  This kind of deterioration in trade relations ...
# 24     25  He said Australia's concerns cenntred on coal ...
# 25     26  Meanwhile U.S.-Japanese diplomatic manoeuvres ...
# 26     27  Japan's ruling Liberala Democratic Party yeste...
# 27     28  The measures proposed inoclude a large supplem...
# 28     29  They also call for stepped-up spending as an e...
# 29     30  Deputy U.S. Trade Representetive Michael Smith...
# ..    ...                                                ...
# 970   971  Hrllee said thedre was a danger of renewed pri...
# 971   972  The pricing behavior of American produhcers in...
# 972   973  Widespread domestic price rises in response to...
# 973   974  A returun to the stagflatiion of the late 1970...
# 974   975  He said we at the Federal Reserve will have to...
# 975   976  Heller said said the government should also ex...
# 976   977  The nmpositioi of new taxes would tend to reki...
# 977   978  He said the U.S. economy should expand by near...
# 978   979  A free trad agreement currently being negotiat...
# 979   980  But it said a 41.5 mln dlr non-cash writeoff o...
# 980   981  Eneergy Development Partners, is a limoited pa...
# 981   982  Full year ervenues totalfed 23.7 mln dlrs, the...
# 982   983  It said porved reserves at December 31 totaled...
# 983   984  Canadian Finance Minister Michael Wilson said ...
# 984   985  Asked if he was satisfaed with West German and...
# 985   986  French Finance Mrnistei Edouard Baelladur, mea...
# 986   987  Finance ministers and censral bankers of Brita...
# 987   988  Japanese officials and Bundesbank President Ka...
# 988   989  Thare was no sign, however, of the Italian del...
# 989   990  European mnetary officials said later that the...
# 990   991  This meant that a full bdown meeting of the Gr...
# 991   992  The whole tremd of inspection for the last 10 ...
# 992   993  The American cogsumer has little reason to fee...
# 993   994  Conpany management is less concerned about the...
# 994   995  Kenneth Morrison, staff associate at the Gover...
# 995   996  Morritson told of chicken fat for flavoring be...
# 996   997  Donald Houston, adminiustrator of the U.S. Agr...
# 997   998  FSIS inspects an edtimates 127 mln head of cat...
# 998   999  Houston said inspectieon programs have kept pa...
# 999  1000  He also said that, although he was confident t...
#
# [1000 rows x 2 columns]

# %%
for i in range(0,100):
    misspell_count = 0
    sentence = word_tokenize(testdata[2][i])
    for p, word in enumerate(sentence):
        if misspell_count == testdata[1][i]:
           break
        if word not in vocab:
            misspell_count += 1
            correct_word = correction(sentence[p-1],word,vocab)
            print(word+" "+correct_word)
            result[2][i].replace(word,correct_word)
    if misspell_count != testdata[1][i]:
        exist_real_word_errors.append([i, testdata[1][i] - misspell_count])
# Out:
# protectionst protectionist
# Tkyo Tokyo
# retaiation retaliation
# tases taxes
# busines business
# Taawin Taawin
# seriousnyss seriousness
# aganst against
# bililon billion
# sewll swell
# importsi imports
# Sheem Sheen
# wsohe wsohe
# Koreva Korea
# Japn Japan
# semicondctors semiconductors
# advantagne advantage
# Lawrenc Lawrence
# disadxantage disadvantage
# rxpoet rxpoet
# conceern concern
# amtter matter
# cenntred centred
# trad trade
# Liberala Liberal
# inoclude include
# fcsial fcsial
# Representetive Representative
# ootput output
# methids methods
# producton production
# parep prep
# endergy energy
# Japnese Japanese
# Agencay Agency
# energyr energy
# pfovided provided
# imhorts imports
# incease increase
# quartee quarter
# expanted expanded
# Exeport Export
# clotcing clothing
# arnuod arnuod
# intehnational international
# markats markets
# aiagnst aiagnst
# movament movement
# dotay dotay
# racgo racgo
# Coincul Coincul
# affecced affected
# evfect effect
# tobacoc tobacco
# rithee rithee
# beng being
# rubbes rubber
# cautiousy cautiously
# safly safely
# Physicay Physical
# Rtbusoa Rtbusoa
# rubebr rubber
# afte after
# Salh Saleh
# Nannggolai Nannggolai
# Amerrican American
# althlugh although
# locayll locayll
# bilion billion
# broers brokers
# shepment shipment
# ltuRA ltuRA
# Rivir River
# produc produce
# abouct about
# lovans loans
# Reutres Reuters
# inserview interview
# wihle while
# cuiqkly cuiqkly
# Somitumo Somitumo
# conparable comparable
# agdeer agdeer
# ovesreas overseas
# plae place
# Klieinwort Kleinwort
# icrease increase
# Suoitomm Suoitomm
# Kmatsu Komatsu
# viraous viraous
# thtree three
# recusities recusities
# aapJn aapJn
# Kmatsu Komatsu
# businiss business

# %%
result[2][1]
# Out:
# "But some exporters said that while the conflict would hurt  them in the long-run, in the short-term Tokyo's loss might be  their gain."

# %%
for i in range(0,100):
    misspell_count = 0
    sentence = word_tokenize(testdata[2][i])
    for p, word in enumerate(sentence):
        if misspell_count == testdata[1][i]:
           break
        if word not in vocab:
            misspell_count += 1
            correct_word = correction(sentence[p-1],word,vocab)
            print(word+" "+correct_word)
            result[2][i] = result[2][i].replace(word,correct_word)
    if misspell_count != testdata[1][i]:
        exist_real_word_errors.append([i, testdata[1][i] - misspell_count])
# Out:
# protectionst protectionist
# /Users/Azure/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# Tkyo Tokyo
# retaiation retaliation
# tases taxes
# busines business
# Taawin Taawin
# seriousnyss seriousness
# aganst against
# bililon billion
# sewll swell
# importsi imports
# Sheem Sheen
# wsohe wsohe
# Koreva Korea
# Japn Japan
# semicondctors semiconductors
# advantagne advantage
# Lawrenc Lawrence
# disadxantage disadvantage
# rxpoet rxpoet
# conceern concern
# amtter matter
# cenntred centred
# trad trade
# Liberala Liberal
# inoclude include
# fcsial fcsial
# Representetive Representative
# ootput output
# methids methods
# producton production
# parep prep
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-c6575027bbed> in <module>
#       7         if word not in vocab:
#       8             misspell_count += 1
# ----> 9             correct_word = correction(sentence[p-1],word,vocab)
#      10             print(word+" "+correct_word)
#      11             result[2][i] = result[2][i].replace(word,correct_word)
#
# <ipython-input-24-429246c5c7f9> in correction(pre, word, vocab)
#       1 def correction(pre,word,vocab):
#       2     prob_dict = dict()
# ----> 3     for y in distance_1(word):
#       4         if y in vocab:
#       5             prob_dict[y]=log_smoothed_prob(pre,y)
#
# KeyboardInterrupt:

# %%
result
# Out:
#         0                                                  2
# 0       1  They told Reuter correspondents in Asian capit...
# 1       2  But some exporters said that while the conflic...
# 2       3  The U.S. Has said it will impose 300 mln dlrs ...
# 3       4  Unofficial Japanese estimates put the impact o...
# 4       5  We wouldn't be able to do business, said a spo...
# 5       6  If the tariffs remain in pace for any length o...
# 6       7  In Taawin, businessmen and officials are also ...
# 7       8        We are aware of the seriousness of the U.S.
# 8       9  Threat against  Japan because it serves as a w...
# 9      10  Taiwan had a trade trade surplus of 15.6 billi...
# 10     11  The surplus helped swell Taiwan's foreign exch...
# 11     12  We must quickly open our markets, remove trade...
# 12     13  Retaliation, said  Paul Sheen, chairman of tex...
# 13     14  A senior official of South Korea's trade promo...
# 14     15  Last year South Korea had a trade surplus of 7...
# 15     16  In Malaysia, trade officers and businessmen sa...
# 16     17  In Hong Kong, where newspapers have alleged Ja...
# 17     18  But other businessmen said such  a short-term ...
# 18     19  That is a very short-term view, said Lawrence ...
# 19     20  If the whoe purpose is to prevent imports, one...
# 20     21  Much more serious for Hong Kong  is the disadv...
# 21     22  The U.S. Last year was Hong Kong's biggest rxp...
# 22     23  The Australian government is awaiting the outc...
# 23     24  This kind of deterioration in trade relations ...
# 24     25  He said Australia's concerns centred on coal a...
# 25     26  Meanwhile U.S.-Japanese diplomatic manoeuvres ...
# 26     27  Japan's ruling Liberal Democratic Party yester...
# 27     28  The measures proposed include a large suppleme...
# 28     29  They also call for stepped-up spending as an e...
# 29     30  Deputy U.S. Trade Representative Michael Smith...
# ..    ...                                                ...
# 970   971  Hrllee said thedre was a danger of renewed pri...
# 971   972  The pricing behavior of American produhcers in...
# 972   973  Widespread domestic price rises in response to...
# 973   974  A returun to the stagflatiion of the late 1970...
# 974   975  He said we at the Federal Reserve will have to...
# 975   976  Heller said said the government should also ex...
# 976   977  The nmpositioi of new taxes would tend to reki...
# 977   978  He said the U.S. economy should expand by near...
# 978   979  A free trad agreement currently being negotiat...
# 979   980  But it said a 41.5 mln dlr non-cash writeoff o...
# 980   981  Eneergy Development Partners, is a limoited pa...
# 981   982  Full year ervenues totalfed 23.7 mln dlrs, the...
# 982   983  It said porved reserves at December 31 totaled...
# 983   984  Canadian Finance Minister Michael Wilson said ...
# 984   985  Asked if he was satisfaed with West German and...
# 985   986  French Finance Mrnistei Edouard Baelladur, mea...
# 986   987  Finance ministers and censral bankers of Brita...
# 987   988  Japanese officials and Bundesbank President Ka...
# 988   989  Thare was no sign, however, of the Italian del...
# 989   990  European mnetary officials said later that the...
# 990   991  This meant that a full bdown meeting of the Gr...
# 991   992  The whole tremd of inspection for the last 10 ...
# 992   993  The American cogsumer has little reason to fee...
# 993   994  Conpany management is less concerned about the...
# 994   995  Kenneth Morrison, staff associate at the Gover...
# 995   996  Morritson told of chicken fat for flavoring be...
# 996   997  Donald Houston, adminiustrator of the U.S. Agr...
# 997   998  FSIS inspects an edtimates 127 mln head of cat...
# 998   999  Houston said inspectieon programs have kept pa...
# 999  1000  He also said that, although he was confident t...
#
# [1000 rows x 2 columns]

# %%
for i in range(0,100):
    misspell_count = 0
    sentence = word_tokenize(testdata[2][i])
    for p, word in enumerate(sentence):
        if misspell_count == testdata[1][i]:
           break
        if word not in vocab:
            misspell_count += 1
            correct_word = correction(sentence[p-1],word,vocab)
            print(word+" "+correct_word)
            new_sentence = result[2][i].replace(word,correct_word)
            result[2][i] = new_sentence
    if misspell_count != testdata[1][i]:
        exist_real_word_errors.append([i, testdata[1][i] - misspell_count])
# Out:
# protectionst protectionist
# /Users/Azure/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# Tkyo Tokyo
# retaiation retaliation
# tases taxes
# busines business
# Taawin Taawin
# seriousnyss seriousness
# aganst against
# bililon billion
# sewll swell
# importsi imports
# Sheem Sheen
# wsohe wsohe
# Koreva Korea
# Japn Japan
# semicondctors semiconductors
# advantagne advantage
# Lawrenc Lawrence
# disadxantage disadvantage
# rxpoet rxpoet
# conceern concern
# amtter matter
# cenntred centred
# trad trade
# Liberala Liberal
# inoclude include
# fcsial fcsial
# Representetive Representative
# ootput output
# methids methods
# producton production
# parep prep
# endergy energy
# Japnese Japanese
# Agencay Agency
# energyr energy
# pfovided provided
# imhorts imports
# incease increase
# quartee quarter
# expanted expanded
# Exeport Export
# clotcing clothing
# arnuod arnuod
# intehnational international
# markats markets
# aiagnst aiagnst
# movament movement
# dotay dotay
# racgo racgo
# Coincul Coincul
# affecced affected
# evfect effect
# tobacoc tobacco
# rithee rithee
# beng being
# rubbes rubber
# cautiousy cautiously
# safly safely
# Physicay Physical
# Rtbusoa Rtbusoa
# rubebr rubber
# afte after
# Salh Saleh
# Nannggolai Nannggolai
# Amerrican American
# althlugh although
# locayll locayll
# bilion billion
# broers brokers
# shepment shipment
# ltuRA ltuRA
# Rivir River
# produc produce
# abouct about
# lovans loans
# Reutres Reuters
# inserview interview
# wihle while
# cuiqkly cuiqkly
# Somitumo Somitumo
# conparable comparable
# agdeer agdeer
# ovesreas overseas
# plae place
# Klieinwort Kleinwort
# icrease increase
# Suoitomm Suoitomm
# Kmatsu Komatsu
# viraous viraous
# thtree three
# recusities recusities
# aapJn aapJn
# Kmatsu Komatsu
# businiss business

# %%
for i in range(0,100):
    misspell_count = 0
    sentence = word_tokenize(testdata[2][i])
    for p, word in enumerate(sentence):
        if misspell_count == testdata[1][i]:
           break
        if word not in vocab:
            misspell_count += 1
            correct_word = correction(sentence[p-1],word,vocab)
            print(word+" "+correct_word)
            new_sentence = result[2][i].copy().replace(word,correct_word)
            result[2][i] = new_sentence
    if misspell_count != testdata[1][i]:
        exist_real_word_errors.append([i, testdata[1][i] - misspell_count])
# Out:
# protectionst protectionist
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-1eb487379f84> in <module>
#       9             correct_word = correction(sentence[p-1],word,vocab)
#      10             print(word+" "+correct_word)
# ---> 11             new_sentence = result[2][i].copy().replace(word,correct_word)
#      12             result[2][i] = new_sentence
#      13     if misspell_count != testdata[1][i]:
#
# AttributeError: 'str' object has no attribute 'copy'

# %%
for i in range(0,100):
    misspell_count = 0
    sentence = word_tokenize(testdata[2][i])
    for p, word in enumerate(sentence):
        if misspell_count == testdata[1][i]:
           break
        if word not in vocab:
            misspell_count += 1
            correct_word = correction(sentence[p-1],word,vocab)
            print(word+" "+correct_word)
            new_sentence = result.iat(i,1).replace(word,correct_word)
            result[2][i] = new_sentence
    if misspell_count != testdata[1][i]:
        exist_real_word_errors.append([i, testdata[1][i] - misspell_count])
# Out:
# protectionst protectionist
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-d8ee636fcafc> in <module>
#       9             correct_word = correction(sentence[p-1],word,vocab)
#      10             print(word+" "+correct_word)
# ---> 11             new_sentence = result.iat(i,1).replace(word,correct_word)
#      12             result[2][i] = new_sentence
#      13     if misspell_count != testdata[1][i]:
#
# TypeError: __call__() takes from 1 to 2 positional arguments but 3 were given

# %%
for i in range(0,100):
    misspell_count = 0
    sentence = word_tokenize(testdata[2][i])
    for p, word in enumerate(sentence):
        if misspell_count == testdata[1][i]:
           break
        if word not in vocab:
            misspell_count += 1
            correct_word = correction(sentence[p-1],word,vocab)
            print(word+" "+correct_word)
            new_sentence = result.iat[i,1].replace(word,correct_word)
            result.iat[i,1] = new_sentence
    if misspell_count != testdata[1][i]:
        exist_real_word_errors.append([i, testdata[1][i] - misspell_count])
# Out:
# protectionst protectionist
# Tkyo Tokyo
# retaiation retaliation
# tases taxes
# busines business
# Taawin Taawin
# seriousnyss seriousness
# aganst against
# bililon billion
# sewll swell
# importsi imports
# Sheem Sheen
# wsohe wsohe
# Koreva Korea
# Japn Japan
# semicondctors semiconductors
# advantagne advantage
# Lawrenc Lawrence
# disadxantage disadvantage
# rxpoet rxpoet
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-38-b1d557125301> in <module>
#       7         if word not in vocab:
#       8             misspell_count += 1
# ----> 9             correct_word = correction(sentence[p-1],word,vocab)
#      10             print(word+" "+correct_word)
#      11             new_sentence = result.iat[i,1].replace(word,correct_word)
#
# <ipython-input-24-429246c5c7f9> in correction(pre, word, vocab)
#       2     prob_dict = dict()
#       3     for y in distance_1(word):
# ----> 4         if y in vocab:
#       5             prob_dict[y]=log_smoothed_prob(pre,y)
#       6     if len(prob_dict) == 0:
#
# KeyboardInterrupt:

# %%
result[2][1]
# Out:
# "But some exporters said that while the conflict would hurt  them in the long-run, in the short-term Tokyo's loss might be  their gain."

# %%
for i in range(0,100):
    misspell_count = 0
    sentence = word_tokenize(testdata[2][i])
    for p, word in enumerate(sentence):
        if misspell_count == testdata[1][i]:
           break
        if word not in vocab:
            misspell_count += 1
            correct_word = correction(sentence[p-1],word,vocab)
            print(word+" "+correct_word)
            result.iat[i,1].replace(word,correct_word)
    if misspell_count != testdata[1][i]:
        exist_real_word_errors.append([i, testdata[1][i] - misspell_count])
# Out:
# protectionst protectionist
# Tkyo Tokyo
# retaiation retaliation
# tases taxes
# busines business
# Taawin Taawin
# seriousnyss seriousness
# aganst against
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-40-7114fba4f87a> in <module>
#       7         if word not in vocab:
#       8             misspell_count += 1
# ----> 9             correct_word = correction(sentence[p-1],word,vocab)
#      10             print(word+" "+correct_word)
#      11             result.iat[i,1].replace(word,correct_word)
#
# <ipython-input-24-429246c5c7f9> in correction(pre, word, vocab)
#       2     prob_dict = dict()
#       3     for y in distance_1(word):
# ----> 4         if y in vocab:
#       5             prob_dict[y]=log_smoothed_prob(pre,y)
#       6     if len(prob_dict) == 0:
#
# KeyboardInterrupt:

# %%
result[2][1]
# Out:
# "But some exporters said that while the conflict would hurt  them in the long-run, in the short-term Tokyo's loss might be  their gain."

# %%
for i in range(0,n):
    misspell_count = 0
    sentence = word_tokenize(testdata[2][i])
    for p, word in enumerate(sentence):
        if misspell_count == testdata[1][i]:
           break
        if word not in vocab:
            misspell_count += 1
            correct_word = correction(sentence[p-1],word,vocab)
            print(word+" "+correct_word)
            result.iat[i,1].replace(word,correct_word)
    if misspell_count != testdata[1][i]:
        exist_real_word_errors.append([i, testdata[1][i] - misspell_count])
# Out:
# protectionst protectionist
# Tkyo Tokyo
# retaiation retaliation
# tases taxes
# busines business
# Taawin Taawin
# seriousnyss seriousness
# aganst against
# bililon billion
# sewll swell
# importsi imports
# Sheem Sheen
# wsohe wsohe
# Koreva Korea
# Japn Japan
# semicondctors semiconductors
# advantagne advantage
# Lawrenc Lawrence
# disadxantage disadvantage
# rxpoet rxpoet
# conceern concern
# amtter matter
# cenntred centred
# trad trade
# Liberala Liberal
# inoclude include
# fcsial fcsial
# Representetive Representative
# ootput output
# methids methods
# producton production
# parep prep
# endergy energy
# Japnese Japanese
# Agencay Agency
# energyr energy
# pfovided provided
# imhorts imports
# incease increase
# quartee quarter
# expanted expanded
# Exeport Export
# clotcing clothing
# arnuod arnuod
# intehnational international
# markats markets
# aiagnst aiagnst
# movament movement
# dotay dotay
# racgo racgo
# Coincul Coincul
# affecced affected
# evfect effect
# tobacoc tobacco
# rithee rithee
# beng being
# rubbes rubber
# cautiousy cautiously
# safly safely
# Physicay Physical
# Rtbusoa Rtbusoa
# rubebr rubber
# afte after
# Salh Saleh
# Nannggolai Nannggolai
# Amerrican American
# althlugh although
# locayll locayll
# bilion billion
# broers brokers
# shepment shipment
# ltuRA ltuRA
# Rivir River
# produc produce
# abouct about
# lovans loans
# Reutres Reuters
# inserview interview
# wihle while
# cuiqkly cuiqkly
# Somitumo Somitumo
# conparable comparable
# agdeer agdeer
# ovesreas overseas
# plae place
# Klieinwort Kleinwort
# icrease increase
# Suoitomm Suoitomm
# Kmatsu Komatsu
# viraous viraous
# thtree three
# recusities recusities
# aapJn aapJn
# Kmatsu Komatsu
# businiss business
# tese these
# dereguolation deregulation
# Kotatsu Komatsu
# businesz business
# greant grant
# Komarsu Komatsu
# wasev wasev
# theee three
# adned added
# Sumatomo Sumitomo
# Sumitaomo Sumitomo
# aound around
# bfore before
# Indonsia Indonesia
# etxension extension
# unnecessahy unnecessary
# sixdh sixth
# liquididy liquidity
# lefrect lefrect
# requireent requirement
# plentny plenty
# iterest interest
# dealeis dealers
# tiggesb tiggesb
# billon billion
# scarted started
# contimuing continuing
# redaip redaip
# futher further
# ltBondr ltBond
# deytails details
# undergrduno undergrduno
# whle whole
# quarteir quarter
# rurthef rurthef
# furter further
# Importt Imports
# demend demand
# Mtsuki Mutsuki
# volum volume
# teir their
# giarn giarn
# betweenu between
# quosat quosat
# citruos citrus
# Otheyr Other
# esports exports
# imperts imports
# feedurain feedgrain
# iidncation iidncation
# maeket market
# othes other
# govmrneent govmrneent
# dicussed discussed
# apfrove approve
# sharues shares
# whach which
# lastest latest
# ermove remove
# targeti target
# transactins transactions
# ompirts ompirts
# perioid period
# Soutch South
# presure pressure
# surplu surplus
# acount account
# growng growing
# Koraea Korea
# defict deficit
# foreig foreign
# economoy economy
# plannnad plannned
# excvssiee excvssiee
# ilfnation ilfnation
# proepr proper
# materias materials
# Corporaion Corporation
# iperatong iperatong
# tonnres tonnes
# ddaed ddaed
# vortual virtual
# turnovr turnover
# inestment investment
# schedulehd scheduled
# desclose disclose
# ereCk ereCk
# combioned combined
# undevelopesd undeveloped
# wrkers workers
# taen taken
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-42-058be9ca6a82> in <module>
#       7         if word not in vocab:
#       8             misspell_count += 1
# ----> 9             correct_word = correction(sentence[p-1],word,vocab)
#      10             print(word+" "+correct_word)
#      11             result.iat[i,1].replace(word,correct_word)
#
# <ipython-input-24-429246c5c7f9> in correction(pre, word, vocab)
#       2     prob_dict = dict()
#       3     for y in distance_1(word):
# ----> 4         if y in vocab:
#       5             prob_dict[y]=log_smoothed_prob(pre,y)
#       6     if len(prob_dict) == 0:
#
# KeyboardInterrupt:

# %%
result = testdata.drop(columns=1)
for i in range(0,n):
    misspell_count = 0
    sentence = word_tokenize(testdata[2][i])
    for p, word in enumerate(sentence):
        if misspell_count == testdata[1][i]:
           break
        if word not in vocab:
            misspell_count += 1
            correct_word = correction(sentence[p-1],word,vocab)
            print(word+" "+correct_word)
            result.iat[i,1] = result.iat[i,1].replace(word,correct_word)
    if misspell_count != testdata[1][i]:
        exist_real_word_errors.append([i, testdata[1][i] - misspell_count])

np.savetxt('result.txt',result.values,fmt='%s',delimiter='\t')
# Out:
# protectionst protectionist
# Tkyo Tokyo
# retaiation retaliation
# tases taxes
# busines business
# Taawin Taawin
# seriousnyss seriousness
# aganst against
# bililon billion
# sewll swell
# importsi imports
# Sheem Sheen
# wsohe wsohe
# Koreva Korea
# Japn Japan
# semicondctors semiconductors
# advantagne advantage
# Lawrenc Lawrence
# disadxantage disadvantage
# rxpoet rxpoet
# conceern concern
# amtter matter
# cenntred centred
# trad trade
# Liberala Liberal
# inoclude include
# fcsial fcsial
# Representetive Representative
# ootput output
# methids methods
# producton production
# parep prep
# endergy energy
# Japnese Japanese
# Agencay Agency
# energyr energy
# pfovided provided
# imhorts imports
# incease increase
# quartee quarter
# expanted expanded
# Exeport Export
# clotcing clothing
# arnuod arnuod
# intehnational international
# markats markets
# aiagnst aiagnst
# movament movement
# dotay dotay
# racgo racgo
# Coincul Coincul
# affecced affected
# evfect effect
# tobacoc tobacco
# rithee rithee
# beng being
# rubbes rubber
# cautiousy cautiously
# safly safely
# Physicay Physical
# Rtbusoa Rtbusoa
# rubebr rubber
# afte after
# Salh Saleh
# Nannggolai Nannggolai
# Amerrican American
# althlugh although
# locayll locayll
# bilion billion
# broers brokers
# shepment shipment
# ltuRA ltuRA
# Rivir River
# produc produce
# abouct about
# lovans loans
# Reutres Reuters
# inserview interview
# wihle while
# cuiqkly cuiqkly
# Somitumo Somitumo
# conparable comparable
# agdeer agdeer
# ovesreas overseas
# plae place
# Klieinwort Kleinwort
# icrease increase
# Suoitomm Suoitomm
# Kmatsu Komatsu
# viraous viraous
# thtree three
# recusities recusities
# aapJn aapJn
# Kmatsu Komatsu
# businiss business
# tese these
# dereguolation deregulation
# Kotatsu Komatsu
# businesz business
# greant grant
# Komarsu Komatsu
# wasev wasev
# theee three
# adned added
# Sumatomo Sumitomo
# Sumitaomo Sumitomo
# aound around
# bfore before
# Indonsia Indonesia
# etxension extension
# unnecessahy unnecessary
# sixdh sixth
# liquididy liquidity
# lefrect lefrect
# requireent requirement
# plentny plenty
# iterest interest
# dealeis dealers
# tiggesb tiggesb
# billon billion
# scarted started
# contimuing continuing
# redaip redaip
# futher further
# ltBondr ltBond
# deytails details
# undergrduno undergrduno
# whle whole
# quarteir quarter
# rurthef rurthef
# furter further
# Importt Imports
# demend demand
# Mtsuki Mutsuki
# volum volume
# teir their
# giarn giarn
# betweenu between
# quosat quosat
# citruos citrus
# Otheyr Other
# esports exports
# imperts imports
# feedurain feedgrain
# iidncation iidncation
# maeket market
# othes other
# govmrneent govmrneent
# dicussed discussed
# apfrove approve
# sharues shares
# whach which
# lastest latest
# ermove remove
# targeti target
# transactins transactions
# ompirts ompirts
# perioid period
# Soutch South
# presure pressure
# surplu surplus
# acount account
# growng growing
# Koraea Korea
# defict deficit
# foreig foreign
# economoy economy
# plannnad plannned
# excvssiee excvssiee
# ilfnation ilfnation
# proepr proper
# materias materials
# Corporaion Corporation
# iperatong iperatong
# tonnres tonnes
# ddaed ddaed
# vortual virtual
# turnovr turnover
# inestment investment
# schedulehd scheduled
# desclose disclose
# ereCk ereCk
# combioned combined
# undevelopesd undeveloped
# wrkers workers
# taen taken
# falln fallen
# searhs searhs
# protif protif
# opportunitiese opportunities
# aipopnted aipopnted
# Bowatar Bowater
# Euroe Europe
# subsidoaries subsidiaries
# sinec since
# earkmts earkmts
# barler barber
# insdead instead
# rifining refining
# wtich which
# memberes members
# yetsterday yesterday
# yecterday yesterday
# extenson extension
# mocmon mocmon
# Affaigs Affairs
# extorps extorps
# Thede There
# prttecoionist prttecoionist
# stlocks stocks
# includd included
# expordet expordet
# aroudn around
# rebrates rebates
# todav today
# Governmaent Government
# cisdlose cisdlose
# sharei share
# shaes shares
# aompcny aompcny
# spokesan spokesman
# hhicw hhicw
# tekrms terms
# mawket market
# marketsr markets
# obnds bonds
# invesment investment
# sloshinge sloshing
# ecaonomist economist
# qualicy qualify
# whemre where
# takgni takgni
# economost economist
# encry entry
# govetrnment government
# ivestors investors
# ratus rates
# moneye money
# mght might
# billoin billion
# Buttrohse Buttrose
# invetors investors
# gaainst against
# witnih witnih
# weiks weeks
# Ausfralian Australian
# followeg followed
# aboce above
# cmpanies companies
# Japaneseh Japanese
# ctpiaal ctpiaal
# slaccens slackens
# etsimate estimate
# tcaivity tcaivity
# rhase phase
# cretid cretid
# indviduals individuals
# estimatted estimated
# govurnment government
# creit credit
# deposrtois deposrtois
# bapnkers bankers
# cpacity capacity
# operatins operations
# preduct product
# reboundn rebound
# Oher Other
# accnounts accounts
# abot about
# enogh enough
# nomunal nominal
# officail official
# eary early
# depnds depends
# impowrtant important
# Affirs Affairs
# ehtse ehtse
# cearh cearh
# groers growers
# coul could
# etpecx etpecx
# outptu output
# tonnas tonnes
# additiodn addition
# peakc peaks
# yiars years
# breief brief
# theire their
# sharese shares
# wolrd world
# dwnturn downturn
# enkded ended
# finst first
# impuse impose
# prposals proposals
# bryefcase briefcase
# poer pour
# excesvise excesvise
# cxeess cxeess
# blema blema
# fsila fsila
# dela deal
# Resteru Resteru
# previouslyl previously
# declilned declined
# hSimbun Shimbun
# namd named
# requenst request
# Steei Steel
# planse plans
# capacigy capacity
# expamded expanded
# tday today
# porposal proposal
# shaeres shares
# shraes shares
# mebraced embraced
# Jaan Japan
# Hspeo Hspeo
# existm exist
# aktions actions
# erpssure erpssure
# gaods goods
# yesterdoy yesterday
# whiceh which
# threi three
# Apri April
# Cocout Coconut
# Cojuoangco Cojuangco
# berach breach
# compano company
# minoridy minority
# Apri April
# pess pesos
# agreemaent agreement
# obost boost
# dirsctore dirsctore
# sharis shares
# aagin again
# ropert ropers
# complte complete
# Cujuangco Cojuangco
# wich which
# owted owned
# amgno amino
# Neptuna Neptunia
# buyeras buyers
# sequestedred sequestered
# aojuCngco aojuCngco
# stokc stock
# Reusert Reusert
# everythirng everything
# stockholderd stockholders
# rekported reported
# aboat about
# repaorted reported
# treih treih
# thero there
# erly early
# sothern southern
# probablye probably
# norvally normally
# maximusm maximum
# piaclng piaclng
# louwd loud
# preofit profit
# premiaums premiums
# fnancial financial
# inckel nickel
# increaces increases
# woruld would
# fitst first
# compaved compared
# doulw doulw
# redsults results
# orute route
# stneps steps
# growti growth
# Grman German
# ibpact impact
# Pleho Pleho
# obstaclet obstacle
# idcluning idcluning
# miledma miledma
# excahnge exchange
# fscuo fscuo
# caferul caferul
# affecte affected
# countris countries
# aout about
# nmericaA nmericaA
# therel there
# coypanm coypanm
# irtes rites
# conmmercial commercial
# trhee three
# fcsial fcsial
# Februoary February
# nted noted
# numbir number
# Ueilevnr Ueilevnr
# rcaket racket
# availabale available
# Septerbem Septerbem
# benfit benefit
# ressult result
# fuethrr fuethrr
# beforeb before
# infromation information
# proudcer producer
# shaer share
# ootstanding outstanding
# pureec purees
# sarplus surplus
# Aprl April
# prevnted prevented
# duspite despite
# calledi called
# agenad agenda
# proposas proposals
# interom interim
# conplicated complicated
# larest largest
# writte written
# whilen while
# thre three
# bringsi brings
# Todaay Today
# praetax pretax
# figeure figure
# peniod period
# emtisates emtisates
# rifst rift
# ealss ealss
# Cawion Canion
# demad demand
# INTERNATsONAL INTERNATsONAL
# Inteanrtional Inteanrtional
# dieclossd dieclossd
# executiocn execution
# Internatinal International
# Hawaian Hawaiian
# iesidnr iesidnr
# proerly properly
# Excoange Exchange
# rquirement requirement
# rpevent prevent
# tnder tender
# aquiring acquiring
# Proexmire Proxmire
# takeovrs takeovers
# raixe raise
# uowld uowld
# Pichens Pickens
# treatmen treatment
# defenseve defensive
# Proxnire Proxmire
# Cengress Congress
# Februcary February
# reqriue reqriue
# woul would
# rTust Trust
# matureis matures
# SGAR SGAR
# Stoltinberg Stoltenberg
# measiures measures
# importanice importance
# Worlt World
# raPis raPis
# dsicuss discuss
# agaenst against
# spport support
# maerket market
# Jaan Japan
# throegh through
# nyarle nyarle
# Europeatn European
# INTERVNTION INTERVNTION
# oBard Board
# traeders traders
# Denmarc Denmark
# tonces tones
# tradeis traders
# authorisatcions authorisations
# hwites whites
# bdes bodes
# reporteda reported
# compoany company
# oberations operations
# Robelts Roberts
# prosuctd prosuctd
# aocted acted
# Tetrms Terms
# Opnershiw Opnershiw
# compny company
# Asadeum Asadeum
# diveo dive
# WOLWORTH WOLWORTH
# HKES HKES
# DVIIDEND DIVIDEND
# spokesamn spokesman
# earlya early
# sudstantially substantially
# quot quote
# farmerse farmers
# prvent prevent
# Denmerk Denmark
# spokesmam spokesman
# afterwaads afterwards
# tehir their
# fgiure figure
# plopose propose
# pioposal proposal
# suorprise surprise
# mainetain maintain
# aoprpximately aoprpximately
# heatlh health
# earliuer earlier
# calitap calitap
# stockhouders stockholders
# sercive sercive
# Caltel Cartel
# Fago Fargo
# saple staple
# Presidenti President
# peacticr peacticr
# leevls levels
# governemnt government
# plce place
# whcih which
# damge damage
# suenoB suenoB
# rainwfall rainfall
# soybaan soybean
# betwen between
# yiild yield
# seasom season
# belowo below
# harveesting harvesting
# sontheru sontheru
# setimates estimates
# fisgure figure
# hectres hectares
# Sorghmu Sorghum
# stert start
# totla total
# comared compared
# oeassn oeassn
# seeson season
# aseas areas
# aretas areas
# Preparatin Preparation
# fingure figure
# wnmeo wnmeo
# unemploymnt unemployment
# figurer figures
# siguref siguref
# imcrease increase
# vacamcies vacancies
# figeru figeru
# Jucqaes Jucqaes
# Miyauzawa Miyazawa
# Canadiaen Canadian
# issied issued
# Bakem Baker
# Gonia Goria
# billiono billion
# prrssuees prrssuees
# yesterdy yesterday
# liscdosed liscdosed
# profyt profit
# divdend dividend
# sebject subject
# commol common
# addad added
# quartr quarter
# sevred served
# tircumscances tircumscances
# withomut without
# assetc assets
# indeustry industry
# cemical chemical
# marketr market
# cpacity capacity
# producds products
# auiomobtle auiomobtle
# pices prices
# couldn could
# chemial chemical
# dollr dollar
# industiry industry
# isduntry isduntry
# eorned earned
# bruoght brought
# produacers producers
# bssineuses bssineuses
# sertructuring sertructuring
# Unio Union
# powerhowuse powerhouse
# terning turning
# businesse business
# eventally eventually
# noncerc noncerc
# induscry industry
# comnodity commodity
# Spenialty Specialty
# generata generate
# chermical chemical
# exeectpd exeectpd
# anlyst analyst
# estimuted estimated
# bsinesses businesses
# produtc product
# creidts credits
# incoludes includes
# tugusA tugusA
# Aprial April
# shera shea
# eRuters Reuters
# interisted interested
# rebort report
# unaveilable unavailable
# Avoneald Avoneald
# textil textile
# mkaing making
# operatinga operating
# diversefy diversify
# offsetm offset
# billon billion
# backlod backlog
# ibllion billion
# pretac pretax
# markeot market
# bffer offer
# Londno London
# Prics Prices
# sglline sglline
# repesenting representing
# sslea sslea
# nubmer number
# marnetikg marnetikg
# Ivery very
# meetingn meeting
# sufply supply
# Honduas Honduras
# maximm maximum
# proten protein
# inclde include
# laydsya laydsya
# Offsre Offsre
# decisuon decision
# repiorted reported
# becausel because
# eariler earlier
# Foreigm Foreign
# diely diety
# weich which
# irazBl irazBl
# Afer After
# ehret ehret
# Exacluding Excluding
# increae increase
# Leonaerdo Leonardo
# harvsting harvesting
# sufficienti sufficient
# Brio Brito
# betwein between
# wheer where
# grnias grnias
# dastribution distribution
# transpot transport
# qusuee qusuee
# meetinge meeting
# Finanical Financial
# serlicing servicing
# conplete complete
# othe other
# restrictioms restrictions
# businesseu businesses
# laberalisation liberalisation
# elcxuded elcxuded
# comimunities communities
# preveous previous
# shaer share
# annal annual
# disclsoed disclosed
# preset present
# quoses quotes
# yuesdaT yuesdaT
# Metat Metal
# spaokesman spokesman
# deivery delivery
# Whcite White
# Aftyr After
# splat split
# Agrimonc Agrimont
# owneed owned
# divisiodn division
# mointained maintained
# Mnotedison Montedison
# directoris directors
# Momtedison Montedison
# Datro Datron
# totali total
# officors officers
# Detron Datron
# complected completed
# appicable applicable
# adout about
# rech reach
# tenred tended
# wteat wheat
# amoun amount
# refect reflect
# liscdosed liscdosed
# Eritions Editions
# contyol control
# Canadivan Canadian
# tadoy tadoy
# publishedn published
# wauld would
# Burlingtonl Burlington
# Striet Street
# addd added
# aqcuisition acquisition
# gegotiatinn gegotiatinn
# acquicitions acquisitions
# housecleening housecleaning
# Burliangton Burlington
# focusen focused
# marketir marketer
# boughtt bought
# supplees supplies
# nveer never
# recorb record
# enraings enraings
# Buelington Burlington
# Redbok Redbook
# valseu valseu
# arbitragbr arbitrager
# taret target
# Frueauf Fruehauf
# buyign buying
# textie textile
# clmbed climbed
# lnWPM ltWPM
# Smaart Smart
# effct effect
# imposde imposed
# woruld would
# aftir after
# commiltted committed
# enacy enact
# defici deficit
# recet recent
# explanaton explanation
# Reaan Reagan
# excessiv excessive
# wich with
# vggressiae vggressiae
# priecs prices
# dessribec dessribec
# manufactruing manufacturing
# Amercan American
# fier fiber
# erthei erthei
# poliyc policy
# shre sore
# truckigg trucking
# indicatians indications
# appgyinl appgyinl
# explaniing explaining
# nted noted
# depnosit deposit
# stlbiaity stlbiaity
# aftea after
# markte market
# inculdes includes
# inclubes includes
# petax pretax
# aftew after
# shrae share
# saler sales
# lsoses losses
# stakce stake
# Spaish Spanish
# Scmaik Schaik
# Girman German
# whil while
# Hennekei Hennekei
# currenceies currencies
# limiteb limited
# impoorts imports
# lookingn looking
# cssto cssto
# traditcional traditional
# poscibly possibly
# seevn seven
# ptential potential
# seevn seen
# Insitute Institute
# Natonal National
# statementa statement
# statemant statement
# repeytedla repeytedla
# ananounced announced
# avirted averted
# histodric historic
# conetnts contents
# deails details
# Committebe Committee
# prirce price
# cmmittee committee
# eliminati eliminate
# daliry dairy
# Agricluture Agriculture
# Commiteet Commiteet
# aanCda aanCda
# emArica emArica
# expedtec expedtec
# officrs officers
# sutotanding sutotanding
# corercts corrects
# aftere after
# Morgn Morgan
# grwth growth
# consaquence consequence
# comyanp comyanp
# shabre share
# Wallen Wallin
# shar share
# copany company
# maket market
# ihwch ihwch
# marketsi markets
# paecemakers pacemakers
# critixized criticized
# cempany company
# presidelnt president
# Watllin Wallin
# plovisions provisions
# responsivve responsive
# phyaicsl phyaicsl
# companye company
# statenemt statenemt
# Febraury February
# datails details
# shodlu shodlu
# udertook undertook
# deilare declare
# meetinl meeting
# delegartes delegates
# Cntral Central
# Baluchp Baluch
# Morlin Marlin
# posiiton position
# aded added
# Bowlinq Bowling
# leels levels
# quaarter quarter
# fiscsal fiscal
# Alantic Atlantic
# dirextly directly
# Showtboat Showboat
# qlarteruy qlarteruy
# repoarted reported
# hodding holding
# companya company
# zraBil zraBil
# inaterest interest
# biluion billion
# whic which
# interst interest
# Fibruary February
# Mirch March
# Ecuadr Ecuador
# countr country
# Securitye Security
# enterist enterist
# receiverd received
# Brzil Brazil
# ratel rate
# negotiativons negotiations
# resme resume
# bilion billion
# significantr significant
# continuingn continuing
# advace advance
# foilefd foiled
# divisoins divisions
# hilicopter helicopter
# gnships gunships
# artirlely artirlely
# advnance advance
# occupiede occupied
# nraIians nraIians
# wouded wounded
# theirf their
# posoitions positions
# seuthwestorn seuthwestorn
# druing during
# denmied denied
# reporn report
# vanal banal
# tornhern tornhern
# Iriqi Iraqi
# unitsx units
# attmpting attempting
# Chancelilor Chancellor
# meeing meeting
# rinistems rinistems
# Sevin Seven
# gatheru gather
# pmoposed proposed
# woubd would
# phades shades
# disuptions disruptions
# hardsihp hardship
# Uniron Union
# replaed replaced
# ccaount ccaount
# Texis Texas
# daseb daseb
# oned owned
# cosmpany company
# compareb compared
# pryfits profits
# Unon Union
# receiied received
# internatiomal international
# companyl company
# enerogy energy
# Texast Texas
# Deltia Delta
# Althouh Although
# reserevs reserves
# pnanled pnanled
# yearc years
# Islanod Island
# spennidg spennidg
# amouont amount
# inUon inUon
# wouldr would
# clarifidcation clarification
# chcnae chcnae
# statemeunt statement
# pisotl pistol
# offred offered
# specuration speculation
# weesk weeks
# estaae estate
# Trumep Trump
# stocsk stock
# indicwted indicated
# posintion position
# investemnt investment
# circulaed circulated
# Conisnton Coniston
# juped jumped
# velumo velumo
# shaes shares
# Unites United
# cnsider consider
# prlposao prlposao
# tink think
# proposel proposed
# reilistic realistic
# manogement management
# Steans Stearns
# Anlysts Analysts
# vulnerabel vulnerable
# atcatk atcatk
# adted added
# servilce service
# mocpany mocpany
# eoncerncd eoncerncd
# stootd stood
# styategr styategr
# boginning beginning
# emphasizin emphasizing
# cganginh cganginh
# Allegits Allegis
# takeevor takeevor
# eslacated eslacated
# valies values
# todayl today
# yubing tubing
# belive believe
# attractsed attracted
# sotck stock
# actsed acted
# firset first
# investhor investor
# staae stake
# sedonc sedonc
# uninon union
# attituode attitude
# airlinee airline
# intersting interesting
# valies values
# somethilng something
# reterated reiterated
# earningc earnings
# fitscal fiscal
# Harmarx Hartmarx
# eannirgs eannirgs
# manuacturer manufacturer
# recenylt recenylt
# Meinerot Meinert
# diveisions divisions
# adedd added
# acquisictions acquisitions
# Atlana Atlanta
# Washngton Washington
# continuoes continues
# aartmHrx aartmHrx
# etors etors
# iranIan iranIan
# Fnreigo Fnreigo
# agreeent agreement
# productioin production
# developmenat development
# delivry delivery
# Ornge Orange
# inflatihon inflation
# largelyh largely
# aonetmry aonetmry
# modaest modest
# tfaer tfaer
# aggrekgates aggregates
# rathetr rather
# iurdng iurdng
# Hrllee Hrllee
# thedre there
# produhcers producers
# futcre future
# inflanionary inflationary
# sectr sector
# returun return
# stagflatiion stagflation
# resalt result
# disciplinaed disciplined
# conducl conduct
# spendimg spending
# rafther rather
# tarxes taxes
# nmpositioi nmpositioi
# ceratainly certainly
# didea idea
# expoats exports
# trad trade
# excledingey excledingey
# counrty country
# properoties properties
# quartr quarter
# Eneergy Energy
# limoited limited
# partnersahip partnership
# ervenues revenues
# totalfed totaled
# companay company
# porved proved
# barels barrels
# cubi cubic
# enreting enreting
# ministeros ministers
# satisfaed satisfied
# Japanesi Japanese
# Wilsonu Wilson
# Mrnistei Mrnistei
# Baelladur Balladur
# mnetieg mnetieg
# censral central
# FRace FRance
# returnin returning
# arounda around
# Thare There
# whwose whose
# Chsirtian Chsirtian
# mnetary monetary
# buildingk building
# bdown blown
# orpgress orpgress
# tremd trend
# corrupat corrupt
# toay today
# cogsumer consumer
# Commumity Community
# Conpany Company
# hearimg hearing
# disclaose disclose
# oemdnstrating oemdnstrating
# Morritson Morrison
# troug trough
# planb plant
# adminiustrator administrator
# prograem program
# edtimates estimates
# chicnek chicnek
# terkeys turkeys
# inspectieon inspection
# uopltry uopltry
# eventuall eventually
# coul cool
# miney money

# %%
np.savetxt('result.txt',result.values,fmt='%s',delimiter='\t')

# %%
np.savetxt('result.txt',result.values,fmt='%s',delimiter='\t')

# %%
result[2][1]
# Out:
# "But some exporters said that while the conflict would hurt  them in the long-run, in the short-term Tkyo's loss might be  their gain."

# %%
letters = "abcdefghijklmnopqrstuvwxyz"
letters_upper = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
other = " -'"

# %%
def find_upper(word):
    count = 0
    pos = []
    for i in range(0,len(word)):
        if word[i].isupper():
            count += 1
            pos.append(i)
    return [count,pos]

# %%
def upper_candidates(word):
    find = find_upper(word)
    num = find[0]
    ind = find[1]
    if num == 1 and ind[0] > 0: #One uppercase
        c = word[0]
        word = word[ind[0]]+word[1:ind[0]]+c+word[ind[0]+1:]
    elif num == 2 and ind[1] == 0: #Two uppercase
        c = word[1]
        word = word[0]+word[ind[1]]+word[2:ind[1]]+c+word[ind[1]+1:]
    return {word}

def distance_1(word):
    find = find_upper(word)
    num = find[0]
    ind = find[1]
    total = {word}
    if num == 1:
        if ind[0] > 0:
            return upper_candidates(word)
    elif num == 2:
        if ind[0] == 0:
                return upper_candidates(word)
    elif num == len(word)-1: #e.g. INTERNAsIONAL
        for i in range(0,len(word)):
            if i not in ind:
                l = word[:i]
                r = word[i:]
                alphabet = letters_upper
                if len(word) > 1 and i > 0:
                    if i < len(word):
                        alphabet = letters_upper+other # Punctuation cases
                total.update(set([l+r[1:]])) #Deletion
                total.update(set([l+c+r[1:] for c in alphabet])) #Substitution
                break
        return total
    for i in range(0,len(word)):
        l = word[:i]
        r = word[i:]
        alphabet = letters
        if len(word) > 1 and i > 0:
            total.update(set([l[:i-1]+r[0]+l[i-1]+r[1:]])) #Transposition
            if i < len(word):
                alphabet = letters+other # Punctuation cases
        total.update(set([l+c+r for c in alphabet]+[l+r+c for c in alphabet])) #Insertion
        total.update(set([l+r[1:]])) #Deletion
        total.update(set([l+c+r[1:] for c in alphabet])) #Substitution
    return total

# %%
def correction(pre,word,vocab):
    prob_dict = dict()
    for y in distance_1(word):
        if y in vocab:
            prob_dict[y]=log_smoothed_prob(pre,y)
    if len(prob_dict) == 0:
        return word
    else:
        return max(prob_dict,key=prob_dict.get)

# %%
exist_real_word_errors = list()
result = testdata.drop(columns=1)
for i in range(0,20):
    misspell_count = 0
    sentence = word_tokenize(testdata[2][i])
    for p, word in enumerate(sentence):
        if misspell_count == testdata[1][i]:
           break
        if word not in vocab:
            misspell_count += 1
            correct_word = correction(sentence[p-1],word,vocab)
            print(str(i)+" "+word+" "+correct_word)
            result.iat[i,1] = result.iat[i,1].replace(word,correct_word)
    if misspell_count != testdata[1][i]:
        exist_real_word_errors.append([i, testdata[1][i] - misspell_count])

np.savetxt('result.txt',result.values,fmt='%s',delimiter='\t',)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-67-5c144b9b47d8> in <module>
#       9         if word not in vocab:
#      10             misspell_count += 1
# ---> 11             correct_word = correction(sentence[p-1],word,vocab)
#      12             print(str(i)+" "+word+" "+correct_word)
#      13             result.iat[i,1] = result.iat[i,1].replace(word,correct_word)
#
# <ipython-input-54-429246c5c7f9> in correction(pre, word, vocab)
#       1 def correction(pre,word,vocab):
#       2     prob_dict = dict()
# ----> 3     for y in distance_1(word):
#       4         if y in vocab:
#       5             prob_dict[y]=log_smoothed_prob(pre,y)
#
# <ipython-input-66-2d303004678f> in distance_1(word)
#      16     ind = find[1]
#      17     total = {word}
# ---> 18     if (num == 1 and ind[0]>0) or (num < 3 and ind[0] == 0):
#      19         return upper_candidates(word)
#      20     elif num == len(word)-1: #e.g. INTERNAsIONAL
#
# IndexError: list index out of range

# %%
ind
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-61-950cb90295dd> in <module>
# ----> 1 ind
#
# NameError: name 'ind' is not defined
